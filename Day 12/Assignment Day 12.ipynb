# %% [markdown]
# # Assignment Day 12

# %%
import pandas as pd 
dataset = pd.read_csv('general_data.csv')
dataset
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
dataset.isnull()
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     False      False           False       False             False
# 1     False      False           False       False             False
# 2     False      False           False       False             False
# 3     False      False           False       False             False
# 4     False      False           False       False             False
# ...     ...        ...             ...         ...               ...
# 4405  False      False           False       False             False
# 4406  False      False           False       False             False
# 4407  False      False           False       False             False
# 4408  False      False           False       False             False
# 4409  False      False           False       False             False
#
#       Education  EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# ...

# %%
dataset.dropna()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %%
dataset.drop_duplicates()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Non - parametric test

# %% [markdown]
# ### 1. Wilcoxson Sign Test -> To compare the 2 paired samples

# %%
from scipy.stats import wilcoxon

d1 = dataset.StockOptionLevel

d2 = dataset.TrainingTimesLastYear

stats,p = wilcoxon( d1 , d2 )

print(stats,p)

print('\nCorrelation :',stats,'\np-value :',p)

if p >= 0.5 :
    print("\nAccept null hypothesis")
elif p < 0.5 :
    print("\nReject null hypothesis \n")
    
print('H0 -> There is no significant difference in StockOptionLevel and TrainingTimesLastYear')
print('HA -> There is significant difference in StockOptionLevel and TrainingTimesLastYear')
# Out:
# 225462.0 0.0
#
# Correlation : 225462.0
# p-value : 0.0
#
# Reject null hypothesis
#
# H0 -> There is no significant difference in StockOptionLevel and TrainingTimesLastYear
# HA -> There is significant difference in StockOptionLevel and TrainingTimesLastYear

# %% [markdown]
# ### 2. Freidman Test -> To compare more than 2 paired samples

# %%
from scipy.stats import friedmanchisquare

d1 = dataset.StockOptionLevel

d2 = dataset.TrainingTimesLastYear

d3 = dataset.YearsSinceLastPromotion

stat,p = friedmanchisquare(d1,d2,d3)

print(stats,p)

print('\nCorrelation :',stats,'\np-value :',p)

if p >= 0.5 :
    print("\nAccept null hypothesis")
elif p < 0.5 :
    print("\nReject null hypothesis ")
    
print('\nH0 -> There is no significant difference in StockOptionLevel ,TrainingTimesLastYear and YearsSinceLastPromotion')
print('HA -> There is significant difference in StockOptionLevel , TrainingTimesLastYear and YearsSinceLastPromotion')
# Out:
# 225462.0 0.0
#
# Correlation : 225462.0
# p-value : 0.0
#
# Reject null hypothesis
#
# H0 -> There is no significant difference in StockOptionLevel ,TrainingTimesLastYear and YearsSinceLastPromotion
# HA -> There is significant difference in StockOptionLevel , TrainingTimesLastYear and YearsSinceLastPromotion

# %% [markdown]
# ### 3. Mann whitney Test -> To compare 2 independent samples

# %%
from scipy.stats import mannwhitneyu

a1 = dataset.JobLevel

a2 = dataset.Education

stat,p = mannwhitneyu(a1,a2)

print(stat,p)

print('\nCorrelation :',stats,'\np-value :',p)

if p >= 0.5 :
    print("\nAccept null hypothesis")
elif p < 0.5 :
    print("\nReject null hypothesis ")
    
print('\nH0 -> There is no significant difference in JobLevel and Education')
print('HA -> There is significant difference in JobLevel and Education')
# Out:
# 5422725.0 1.0508689971208418e-301
#
# Correlation : 225462.0
# p-value : 1.0508689971208418e-301
#
# Reject null hypothesis
#
# H0 -> There is no significant difference in JobLevel and Education
# HA -> There is significant difference in JobLevel and Education

# %% [markdown]
# ### 4. Krushkal Wallis Test -> To compare more than 2 independent samples

# %%
dataset["Attrition"] = dataset["Attrition"].map({"Yes":1,"No":0})
dataset
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      51          0      Travel_Rarely                   Sales
# 1      31          1  Travel_Frequently  Research & Development
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4405   42          0      Travel_Rarely  Research & Development
# 4406   29          0      Travel_Rarely  Research & Development
# 4407   25          0      Travel_Rarely  Research & Development
# 4408   42          0      Travel_Rarely                   Sales
# 4409   40          0      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
from scipy.stats import kruskal

a3 = dataset.Attrition

stat,p=kruskal(a1,a2,a3)

print(stat,p)

print('\nCorrelation :',stats,'\np-value :',p)

if p >= 0.5 :
    print("\nAccept null hypothesis")
elif p < 0.5 :
    print("\nReject null hypothesis ")

print('\nH0 -> There is no significant difference in JobLevel, Education and Attrition')
print('HA -> There is significant difference in JobLevel, Education and Attrition')
# Out:
# 9190.473391894182 0.0
#
# Correlation : 225462.0
# p-value : 0.0
#
# Reject null hypothesis
#
# H0 -> There is no significant difference in JobLevel, Education and Attrition
# HA -> There is significant difference in JobLevel, Education and Attrition

# %% [markdown]
# ### 5. Chi square test -> To check the dependency of the variables. Variables should be categorical

# %%
from scipy.stats import chi2_contingency

b1 = dataset.Attrition
b2 = dataset.Gender

chitable = pd.crosstab( b1,b2)

chitable
# Out:
# Gender     Female  Male
# Attrition
# 0            1494  2205
# 1             270   441

# %%
stats,p,dof,expeted = chi2_contingency(chitable)

print(stats,p)

print('\nCorrelation :',stats,'\np-value :',p)

if p >= 0.5 :
    print("\nAccept null hypothesis")
elif p < 0.5 :
    print("\nReject null hypothesis ")
    
print('\nH0 -> There is no dependency b/w Attrition and Gender')
print('Ha -> There is dependency b/w Attrition and Gender')
# Out:
# 1.349904410246582 0.24529482862926827
#
# Correlation : 1.349904410246582
# p-value : 0.24529482862926827
#
# Reject null hypothesis
#
# H0 -> There is no dependency b/w Attrition and Gender
# Ha -> There is dependency b/w Attrition and Gender

# %% [markdown]
# ---

# %% [markdown]
# # Parametric test

# %% [markdown]
# ### 1. One Sample Test -> To compare the sample mean with population mean

# %%
from scipy.stats import ttest_1samp

m1 = dataset.MonthlyIncome

stat,p = ttest_1samp( m1 , 65)

print(stats,p)

print('\nCorrelation :',stats,'\np-value :',p)

if p >= 0.5 :
    print("\nAccept null hypothesis")
elif p < 0.5 :
    print("\nReject null hypothesis ")

print('\nH0 -> There is no significant difference of the mean of Employee MonthlyIncome against population mean = 65')
print('H1 -> There is significant difference of the mean of Employee MonthlyIncome against population mean = 65')
# Out:
# 1.349904410246582 0.0
#
# Correlation : 1.349904410246582
# p-value : 0.0
#
# Reject null hypothesis
#
# H0 -> There is no significant difference of the mean of Employee MonthlyIncome against population mean = 65
# H1 -> There is significant difference of the mean of Employee MonthlyIncome against population mean = 65

# %% [markdown]
# ### 2.Two sample paired t test -> To compare the mean of 2 paired samples

# %%
from scipy.stats import ttest_rel

p1 = dataset.YearsSinceLastPromotion
p2 = dataset.YearsAtCompany

stat,p=ttest_rel(p1,p2)

print(stats,p)

print('\nCorrelation :',stats,'\np-value :',p)

if p >= 0.5 :
    print("\nAccept null hypothesis")
elif p < 0.5 :
    print("\nReject null hypothesis ")

print('\nH0 -> There is no significant difference in the mean of YearsSinceLastPromotion and YearsAtCompany')
print('H1 -> There is significant difference in the mean of YearsSinceLastPromotion and YearsAtCompany')
# Out:
# 1.349904410246582 0.0
#
# Correlation : 1.349904410246582
# p-value : 0.0
#
# Reject null hypothesis
#
# H0 -> There is no significant difference in the mean of YearsSinceLastPromotion and YearsAtCompany
# H1 -> There is significant difference in the mean of YearsSinceLastPromotion and YearsAtCompany

# %% [markdown]
# ### 3. Two Sample independent T-Test -> To compare the mean of 2 independent samples

# %%
from scipy.stats import ttest_ind

z1=dataset.Age

z2=dataset.Education

stat,p=ttest_ind(z1,z2)

print(stat,p)

print(stats,p)

print('\nCorrelation :',stats,'\np-value :',p)

if p >= 0.5 :
    print("\nAccept null hypothesis")
elif p < 0.5 :
    print("\nReject null hypothesis ")

print('\nH0 -> There is no significant difference in the mean of Employee b/w Age and Education')
print('H1 -> There is significant difference in the mean of Employee b/w Age and Education')
# Out:
# 245.75208220002168 0.0
# 1.349904410246582 0.0
#
# Correlation : 1.349904410246582
# p-value : 0.0
#
# Reject null hypothesis
#
# H0 -> There is no significant difference in the mean of Employee b/w Age and Education
# H1 -> There is significant difference in the mean of Employee b/w Age and Education
